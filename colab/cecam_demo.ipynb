# %% [markdown]
# # CECAM demo — Colab fallback
# Zero local setup. Run the cells top to bottom to reproduce the honest baseline (`mass_gate: PASS`). To drive the *agent* loop you still need your own agent/API key; this fallback covers the run-and-watch path.

# %%
# 1. Get the repo
# !git clone https://github.com/BoltMaxwell/cecam-demo.git
# %cd cecam-demo

# %%
# 2. Install dependencies (Colab has no uv by default)
# !pip -q install 'numpyro>=0.15' 'jax>=0.4' 'numpy>=1.26' 'matplotlib>=3.8'

# %%
# 3. Run the baseline and read the gate
# !python train.py | grep -E '^elbo:|^mass_gate:'

# %% [markdown]
# Expected: `mass_gate: PASS` and `elbo:` around 44 — the conserving baseline. See `cheat-reveal/` for what an *ungated* agent does instead, and `AGENTS.md` for the harnessed loop your agent should follow.
